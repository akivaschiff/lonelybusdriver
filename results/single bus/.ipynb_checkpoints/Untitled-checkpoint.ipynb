# %%
import pandas
import matplotlib
# %matplotlib inline

all_h = {'distance_waiting_ratio': {1: (0.0, 0, 0), 2: (0.0, 38.48376280978771, 4), 3: (0.0, 143.2249271240711, 9), 4: (0.0, 130.71837076581286, 37), 5: (0.10900020599365234, 155.9308580080245, 138), 6: (0.24500012397766113, 160.88811608797334, 821), 7: (3.325000047683716, 272.74753110653745, 8271), 8: (10.306999921798706, 234.9991502426175, 16405)}, 'nullHeuristic': {1: (0.0, 0, 0), 2: (0.0, 38.48376280978771, 4), 3: (0.0, 143.2249271240711, 14), 4: (0.0, 130.71837076581286, 115), 5: (0.1400001049041748, 155.9308580080245, 247), 6: (3.6570000648498535, 160.88811608797334, 11327), 7: (3.870999813079834, 196.11123018316394, 7977), 8: (205.96000003814697, 227.83767415247434, 105835)}, 'satisfied_customers': {1: (0.0, 0, 0), 2: (0.0, 38.48376280978771, 3), 3: (0.0, 143.2249271240711, 14), 4: (0.015000104904174805, 130.71837076581286, 109), 5: (0.10899996757507324, 155.9308580080245, 185), 6: (3.1430001258850098, 160.88811608797334, 9605), 7: (2.81499981880188, 196.11123018316394, 6879), 8: (132.70700001716614, 227.83767415247434, 82284)}, 'total_destination_left_heuristic': {1: (0.0, 0, 0), 2: (0.0, 38.48376280978771, 2), 3: (0.0, 143.2249271240711, 12), 4: (0.014999866485595703, 130.71837076581286, 55), 5: (0.015999794006347656, 155.9308580080245, 8), 6: (0.11099982261657715, 160.88811608797334, 252), 7: (0.0, 196.11123018316394, 8), 8: (0.046000003814697266, 249.20792479106672, 95)}, 'onboard_passengers': {1: (0.0, 0, 0), 2: (0.0, 38.48376280978771, 3), 3: (0.016000032424926758, 143.2249271240711, 14), 4: (0.014999866485595703, 130.71837076581286, 109), 5: (0.07800006866455078, 155.9308580080245, 158), 6: (3.940000057220459, 160.88811608797334, 9227), 7: (3.003000020980835, 196.11123018316394, 6366), 8: (53.44599986076355, 227.83767415247434, 74633)}, 'combined_total_destination_onboard': {1: (0.0, 0, 0), 2: (0.0, 38.48376280978771, 2), 3: (0.0, 143.2249271240711, 12), 4: (0.016000032424926758, 130.71837076581286, 47), 5: (0.0, 155.9308580080245, 10), 6: (0.07800006866455078
, 160.88811608797334, 145), 7: (0.0, 196.11123018316394, 8), 8: (0.03099989891052246, 249.20792479106672, 67)}}


aStarRes = {1: (0.0, 0, 1), 2: (0.0, 38, 2), 3: (0.0, 143, 6), 4: (0.03099989891052246, 129, 74), 5: (0.015000104904174805, 155, 63), 6: (0.25, 131, 468), 7: (2.5420000553131104, 194, 3216), 8: (13.361999988555908, 225, 12659), 9: (161.4649999141693, 235, 114243)}
all_h
# Out:
# {'combined_total_destination_onboard': {1: (0.0, 0, 0),
#   2: (0.0, 38.48376280978771, 2),
#   3: (0.0, 143.2249271240711, 12),
#   4: (0.016000032424926758, 130.71837076581286, 47),
#   5: (0.0, 155.9308580080245, 10),
#   6: (0.07800006866455078, 160.88811608797334, 145),
#   7: (0.0, 196.11123018316394, 8),
#   8: (0.03099989891052246, 249.20792479106672, 67)},
#  'distance_waiting_ratio': {1: (0.0, 0, 0),
#   2: (0.0, 38.48376280978771, 4),
#   3: (0.0, 143.2249271240711, 9),
#   4: (0.0, 130.71837076581286, 37),
#   5: (0.10900020599365234, 155.9308580080245, 138),
#   6: (0.24500012397766113, 160.88811608797334, 821),
#   7: (3.325000047683716, 272.74753110653745, 8271),
#   8: (10.306999921798706, 234.9991502426175, 16405)},
#  'nullHeuristic': {1: (0.0, 0, 0),
#   2: (0.0, 38.48376280978771, 4),
#   3: (0.0, 143.2249271240711, 14),
#   4: (0.0, 130.71837076581286, 115),
#   5: (0.1400001049041748, 155.9308580080245, 247),
# ...

# %%
all_h.keys()
# Out:
# ['distance_waiting_ratio',
#  'nullHeuristic',
#  'satisfied_customers',
#  'total_destination_left_heuristic',
#  'onboard_passengers',
#  'combined_total_destination_onboard']

# %%
def plotNames(names, index, legend=True, _min=None, _max=None):
    plots = []
    for n in names:
        ob = all_h[n]
        nodes = ob.keys()
        exp = [ob[k][index] for k in nodes]
        x, = matplotlib.pyplot.plot(nodes, exp, label=n)
        plots.append(x)
    if legend:
        matplotlib.pyplot.legend(handles=plots)
    matplotlib.pyplot.show()

"""
plotNames(['distance_waiting_ratio',
 'nullHeuristic',
 'satisfied_customers',
 'total_destination_left_heuristic',
 'onboard_passengers',
 'combined_total_destination_onboard'], 2)
"""

plotNames(['combined_total_destination_onboard',
 'total_destination_left_heuristic'], 2)

# %%
plotNames(['distance_waiting_ratio',
 'nullHeuristic',
 'satisfied_customers',
 'onboard_passengers'], 2)

# %%
plotNames([
 'nullHeuristic'], 2, True)

# %%
import networkx

g = networkx.Graph()

g.get_edge_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-7317e09005d9> in <module>()
#       3 g = networkx.Graph()
#       4
# ----> 5 g.get_edge_data()
#
# TypeError: get_edge_data() takes at least 3 arguments (1 given)

# %%
plotNames([
 'nullHeuristic',
 'total_destination_left_heuristic'], 1, True)

# %%
y = {1: 0.0009999275207519531, 2: 0.0010001659393310547, 3: 0.0009999275207519531, 4: 0.0, 5: 0.0019998550415039062, 6: 0.0009999275207519531, 7: 0.0009999275207519531, 8: 0.002000093460083008, 9: 0.0019998550415039062, 10: 0.002000093460083008, 11: 0.0029997825622558594, 12: 0.003000020980834961, 13: 0.003000020980834961, 14: 0.005000114440917969}

all_h["polyAlgo"] = {t: (y[t], 0, 0) for t in y}
all_h
# Out:
# {'combined_total_destination_onboard': {1: (0.0, 0, 0),
#   2: (0.0, 38.48376280978771, 2),
#   3: (0.0, 143.2249271240711, 12),
#   4: (0.016000032424926758, 130.71837076581286, 47),
#   5: (0.0, 155.9308580080245, 10),
#   6: (0.07800006866455078, 160.88811608797334, 145),
#   7: (0.0, 196.11123018316394, 8),
#   8: (0.03099989891052246, 249.20792479106672, 67)},
#  'distance_waiting_ratio': {1: (0.0, 0, 0),
#   2: (0.0, 38.48376280978771, 4),
#   3: (0.0, 143.2249271240711, 9),
#   4: (0.0, 130.71837076581286, 37),
#   5: (0.10900020599365234, 155.9308580080245, 138),
#   6: (0.24500012397766113, 160.88811608797334, 821),
#   7: (3.325000047683716, 272.74753110653745, 8271),
#   8: (10.306999921798706, 234.9991502426175, 16405)},
#  'nullHeuristic': {1: (0.0, 0, 0),
#   2: (0.0, 38.48376280978771, 4),
#   3: (0.0, 143.2249271240711, 14),
#   4: (0.0, 130.71837076581286, 115),
#   5: (0.1400001049041748, 155.9308580080245, 247),
# ...

# %%
plotNames([
 "nullHeuristic"], 0, True)

# %%
more_h = {'onboard_heuristic': {1: (0.06700015068054199, 2), 2: (0.059999942779541016, 24), 3: (0.4460000991821289, 889), 4: (9.032999992370605, 11346), 5: (29.766000032424927, 30001)}, 'null': {1: (0.0559999942779541, 2), 2: (0.05900001525878906, 24), 3: (0.47499990463256836, 935), 4: (9.196000099182129, 11655), 5: (29.99399995803833, 30001)}, 'maximal_destination_for_passenger': {1: (0.0559999942779541, 2), 2: (0.059999942779541016, 22), 3: (0.4479999542236328, 902), 4: (9.361999988555908, 11974), 5: (30.180000066757202, 30001)}, 'satisfied_heuristic': {1: (0.0559999942779541, 2), 2: (0.059999942779541016, 22), 3: (0.4780001640319824, 907), 4: (10.195000171661377, 12858), 5: (29.77500009536743, 30001)}}
def plotNames(names, index, legend=True, _min=None, _max=None):
    plots = []
    for n in names:
        ob = more_h[n]
        nodes = ob.keys()
        exp = [ob[k][index] for k in nodes]
        x, = matplotlib.pyplot.plot(nodes, exp, label=n)
        plots.append(x)
    if legend:
        matplotlib.pyplot.legend(handles=plots)
    matplotlib.pyplot.show()

# %%
plotNames(more_h.keys(), 1, True)

# %%
plotNames(more_h.keys(), 0, True)

# %%
more_h
# Out:
# {'maximal_destination_for_passenger': {1: (0.0559999942779541, 2),
#   2: (0.059999942779541016, 22),
#   3: (0.4479999542236328, 902),
#   4: (9.361999988555908, 11974),
#   5: (30.180000066757202, 30001)},
#  'null': {1: (0.0559999942779541, 2),
#   2: (0.05900001525878906, 24),
#   3: (0.47499990463256836, 935),
#   4: (9.196000099182129, 11655),
#   5: (29.99399995803833, 30001)},
#  'onboard_heuristic': {1: (0.06700015068054199, 2),
#   2: (0.059999942779541016, 24),
#   3: (0.4460000991821289, 889),
#   4: (9.032999992370605, 11346),
#   5: (29.766000032424927, 30001)},
#  'satisfied_heuristic': {1: (0.0559999942779541, 2),
#   2: (0.059999942779541016, 22),
#   3: (0.4780001640319824, 907),
#   4: (10.195000171661377, 12858),
#   5: (29.77500009536743, 30001)}}

# %%
approx = {'hub_algo': {0: (0.27900004386901855, 16.0), 1: (0.315000057220459, 26.0), 2: (0.28299999237060547, 26.0), 3: (0.31400012969970703, 17.0), 4: (0.2869999408721924, 20.0), 5: (0.5840001106262207, 31.0), 6: (3.7750000953674316, 31.0), 7: (0.33299994468688965, 20.0)}, 'floyd_warshall_solution_remove_stations': {0: (0.0009999275207519531, 0), 1: (0.0010001659393310547, 0), 2: (0.0, 14.142135623730951), 3: (0.0010001659393310547, 5.830951894845301), 4: (0.0009999275207519531, 19.242597635797498), 5: (0.0009999275207519531, 25.325360166095717), 6: (0.0009999275207519531, 18.0), 7: (0.0010001659393310547, 34.46242238584557)}}
def plotNames(names, index, legend=True, _min=None, _max=None):
    plots = []
    for n in names:
        ob = approx[n]
        nodes = ob.keys()
        exp = [ob[k][index] for k in nodes]
        x, = matplotlib.pyplot.plot(nodes, exp, label=n)
        plots.append(x)
    if legend:
        matplotlib.pyplot.legend(handles=plots)
    matplotlib.pyplot.show()

# %%
plotNames(['hub_algo'], 1)

# %%
plotNames(approx.keys(), 0)
